# %%
def read_file(filepath):
    
    with open(filepath) as f:
        str_text = f.read()
    return str_text

# %%
read_file('wonderland.txt')
# Out:
# 'Alice was beginning to get very tired of sitting by her sister on the\nbank, and of having nothing to do: once or twice she had peeped into the\nbook her sister was reading, but it had no pictures or conversations in\nit, \'and what is the use of a book,\' thought Alice \'without pictures or\nconversations?\'\nSo she was considering in her own mind (as well as she could, for the\nhot day made her feel very sleepy and stupid), whether the pleasure\nof making a daisy-chain would be worth the trouble of getting up and\npicking the daisies, when suddenly a White Rabbit with pink eyes ran\nclose by her.\nThere was nothing so VERY remarkable in that; nor did Alice think it so\nVERY much out of the way to hear the Rabbit say to itself, \'Oh dear!\nOh dear! I shall be late!\' (when she thought it over afterwards, it\noccurred to her that she ought to have wondered at this, but at the time\nit all seemed quite natural); but when the Rabbit actually TOOK A WATCH\nOUT OF ITS WAISTCOAT-POCKET, and looked at it, and then hurried on,\nAlice started to her feet, for it flashed across her mind that she had\nnever before seen a rabbit with either a waistcoat-pocket, or a watch\nto take out of it, and burning with curiosity, she ran across the field\nafter it, and fortunately was just in time to see it pop down a large\nrabbit-hole under the hedge.\nIn another moment down went Alice after it, never once considering how\nin the world she was to get out again.\nThe rabbit-hole went straight on like a tunnel for some way, and then\ndipped suddenly down, so suddenly that Alice had not a moment to think\nabout stopping herself before she found herself falling down a very deep\nwell.\nEither the well was very deep, or she fell very slowly, for she had\nplenty of time as she went down to look about her and to wonder what was\ngoing to happen next. First, she tried to look down and make out what\nshe was coming to, but it was too dark to see anything; then she\nlooked at the sides of the well, and noticed that they were filled with\ncupboards and book-shelves; here and there she saw maps and pictures\nhung upon pegs. She took down a jar from one of the shelves as\nshe passed; it was labelled \'ORANGE MARMALADE\', but to her great\ndisappointment it was empty: she did not like to drop the jar for fear\nof killing somebody, so managed to put it into one of the cupboards as\nshe fell past it.\n\'Well!\' thought Alice to herself, \'after such a fall as this, I shall\nthink nothing of tumbling down stairs! How brave they\'ll all think me at\nhome! Why, I wouldn\'t say anything about it, even if I fell off the top\nof the house!\' (Which was very likely true.)\nDown, down, down. Would the fall NEVER come to an end! \'I wonder how\nmany miles I\'ve fallen by this time?\' she said aloud. \'I must be getting\nsomewhere near the centre of the earth. Let me see: that would be four\nthousand miles down, I think--\' (for, you see, Alice had learnt several\nthings of this sort in her lessons in the schoolroom, and though this\nwas not a VERY good opportunity for showing off her knowledge, as there\nwas no one to listen to her, still it was good practice to say it over)\n\'--yes, that\'s about the right distance--but then I wonder what Latitude\nor Longitude I\'ve got to?\' (Alice had no idea what Latitude was, or\nLongitude either, but thought they were nice grand words to say.)\nPresently she began again. \'I wonder if I shall fall right THROUGH the\nearth! How funny it\'ll seem to come out among the people that walk with\ntheir heads downward! The Antipathies, I think--\' (she was rather glad\nthere WAS no one listening, this time, as it didn\'t sound at all the\nright word) \'--but I shall have to ask them what the name of the country\nis, you know. Please, Ma\'am, is this New Zealand or Australia?\' (and\nshe tried to curtsey as she spoke--fancy CURTSEYING as you\'re falling\nthrough the air! Do you think you could manage it?) \'And what an\nignorant little gir ...

# %%
import spacy
import string
from string import punctuation
nlp = spacy.load('en_core_web_sm',disable=['parser', 'tagger','ner'])

nlp.max_length = 1000000

# %%
def separate_punc(doc_text):
    return [token.text.lower() for token in nlp(doc_text) if token.text not in '\n\n \n\n\n!"-#$%&()--.*\n  +,-/:;<=>?@[\\]^_`{|}~\t\n ']

# %%
raw_text = read_file('wonderland.txt')
raw_text = [s for s in raw_text if s not in string.punctuation]
raw_text = "".join(raw_text)
tokens = separate_punc(raw_text)

# %%
len(tokens)
# Out:
# 26931

# %%
# organize into sequences of tokens
train_len = 25+1 # 50 training words , then one target word

# Empty list of sequences
text_sequences = []

for i in range(train_len, len(tokens)):
    
    # Grab train_len# amount of characters
    seq = tokens[i-train_len:i]
    
    # Add to list of sequences
    text_sequences.append(seq)

# %%
' '.join(text_sequences[0])
# Out:
# 'alice was beginning to get very tired of sitting by her sister on the bank and of having nothing to do once or twice she had'

# %%
' '.join(text_sequences[1])
# Out:
# 'was beginning to get very tired of sitting by her sister on the bank and of having nothing to do once or twice she had peeped'

# %%
len(text_sequences)
# Out:
# 26905

# %%
from keras.preprocessing.text import Tokenizer
# Out:
# Using TensorFlow backend.

# %%
# integer encode sequences of words
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
sequences[0]
# Out:
# [11,
#  12,
#  298,
#  3,
#  102,
#  29,
#  515,
#  7,
#  375,
#  79,
#  16,
#  457,
#  19,
#  1,
#  1454,
#  2,
#  7,
#  374,
#  134,
#  3,
#  31,
#  141,
#  59,
#  672,
#  5,
#  20]

# %%
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'and',
#  3: 'to',
#  4: 'a',
#  5: 'she',
#  6: 'it',
#  7: 'of',
#  8: 'i',
#  9: 'said',
#  10: 'you',
#  11: 'alice',
#  12: 'was',
#  13: 'in',
#  14: 'that',
#  15: 'as',
#  16: 'her',
#  17: 'nt',
#  18: 'at',
#  19: 'on',
#  20: 'had',
#  21: 'with',
#  22: 'all',
#  23: 'but',
#  24: 'for',
#  25: 'so',
#  26: 'they',
#  27: 'be',
#  28: 'not',
#  29: 'very',
#  30: 'what',
#  31: 'do',
#  32: 'this',
#  33: 'little',
#  34: 'he',
#  35: 'out',
#  36: 'its',
#  37: 'is',
#  38: 'one',
#  39: 'down',
#  40: 'there',
#  41: 'up',
#  42: 'would',
#  43: 'his',
#  44: 'about',
#  45: 'if',
#  46: 'then',
#  47: 'have',
#  48: 'were',
#  49: 'no',
#  50: 'could',
#  51: 'like',
#  52: 'know',
#  53: 'them',
#  54: 'went',
#  55: 'herself',
#  56: 'again',
#  57: 'when',
#  58: 'did',
#  59: 'or',
#  60: 'thought',
#  61: 'off',
#  62: 's',
#  63: 'time',
#  64: 'me',
#  65: 'queen',
#  66: 'into',
#  67: 'see',
#  68: 'how',
#  69: 'your',
#  70: 'who',
#  71: 'king',
#  72: 'well',
#  73: 'm',
#  74: 'began',
#  75: 'my',
#  76: 'an',
#  77: 'now',
#  78: 'turtle',
#  79: 'by',
#  80: 'quite',
#  81: 'hatter',
#  82: 'mock',
#  83: 'gryphon',
#  84: 'think',
#  85: 'are',
#  86: 'way',
#  87: 'their',
#  88: 'much',
#  89: 'just',
#  90: 'some',
#  91: 'say',
#  92: 'go',
#  93: 'first',
#  94: 'which',
#  95: 'only',
#  96: 'thing',
#  97: 'here',
#  98: 'head',
#  99: 'more',
#  100: 'voice',
#  101: '\n   ',
#  102: 'get',
#  103: 'looked',
#  104: 'never',
#  105: 'come',
#  106: 'got',
#  107: 'must',
#  108: 'rabbit',
#  109: 'after',
#  110: 've',
#  111: 'such',
#  112: 'round',
#  113: 'him',
#  114: 'over',
#  115: 'came',
#  116: 'tone',
#  117: 'great',
#  118: 'why',
#  119: 'other',
#  120: 'any',
#  121: 'two',
#  122: 'duchess',
#  123: 'dormouse',
#  124: 'oh',
#  125: 'mouse',
#  126: 'been',
#  127: 'back',
#  128: 'before',
#  129: 're',
#  130: '\n    ',
#  131: 'from',
#  132: 'cat',
#  133: 'can',
#  134: 'nothing',
#  135: 'large',
#  136: 'ill',
#  137: 'last',
#  138: 'march',
#  139: 'found',
#  140: 'should',
#  141: 'once',
#  142: 'put',
#  143: 'right',
#  144: 'tell',
#  145: 'long',
#  146: 'will',
#  147: 'we',
#  148: 'hare',
#  149: 'made',
#  150: 'white',
#  151: 'next',
#  152: 'heard',
#  153: 'looking',
#  154: 'dear',
#  155: 'moment',
#  156: 'door',
#  157: 'replied',
#  158: 'look',
#  159: 'things',
#  160: 'might',
#  161: 'ca',
#  162: 'eyes',
#  163: 'seemed',
#  164: 'going',
#  165: 'poor',
#  166: 'make',
#  167: 'too',
#  168: 'upon',
#  169: 'd',
#  170: 'three',
#  171: 'caterpillar',
#  172: 'without',
#  173: 'day',
#  174: 'shall',
#  175: 'rather',
#  176: 'soon',
#  177: 'away',
#  178: 'does',
#  179: 'took',
#  180: 'good',
#  181: 'than',
#  182: 'while',
#  183: 'same',
#  184: 'sure',
#  185: 'wo',
#  186: 'course',
#  187: 'felt',
#  188: 'added',
#  189: 'getting',
#  190: 'another',
#  191: 'yet',
#  192: 'take',
#  193: 'words',
#  194: 'wish',
#  195: 'ever',
#  196: 'half',
#  197: 'minute',
#  198: 'till',
#  199: 'find',
#  200: 'sort',
#  201: 'hand',
#  202: 'however',
#  203: 'cried',
#  204: 'feet',
#  205: 'tried',
#  206: 'anything',
#  207: 'll',
#  208: 'even',
#  209: 'please',
#  210: 'curious',
#  211: 'being',
#  212: 'old',
#  213: 'use',
#  214: 'wonder',
#  215: 'house',
#  216: 'eat',
#  217: 'table',
#  218: '\n     ',
#  219: 'something',
#  220: 'soup',
#  221: 'court',
#  222: 'end',
#  223: 'let',
#  224: 'perhaps',
#  225: 'talking',
#  226: 'question',
#  227: 'side',
#  228: 'sat',
#  229: 'enough',
#  230: 'asked',
#  231: 'jury',
#  232: 'ran',
#  233: 'under',
#  234: 'bit',
#  235: 'turned',
#  236: 'high',
#  237: 'indeed',
#  238: 'hastily',
#  239: 'spoke',
#  240: 'near',
#  241: 'idea',
#  242: 'cats',
#  243: 'saying',
#  244: 'garden',
#  245: 'knew',
#  246: 'because',
#  247: 'gave',
#  248: 'am',
#  249: 'done',
#  250: 'called',
#  251: 'where',
#  252: 'hear',
#  253: 'itself',
#  254: 'ought',
#  255: 'seen',
#  256: 'saw',
#  257: 'through',
#  258: 'air',
#  259: 'remember',
#  260: 'low',
#  261: 'trying',
#  262: 'certainly',
#  263: 'face',
#  264: 'left',
#  265: 'anxiously',
#  266: 'set',
#  267: 'speak',
#  268: 'change',
#  269: 'these',
#  270: 'suppose',
#  271: 'talk',
#  272: 'us',
#  273: 'better',
#  274: 'silence',
#  275: 'both',
#  276: 'may',
#  277: 'beautiful',
#  278: 'suddenly',
#  279: 'close',
#  280: 'still',
#  281: 'yes',
#  282: 'people',
#  283: 'behind',
#  284: 'begin',
#  285: 'really',
#  286: 'size',
#  287: 'grow',
#  288: 'far',
#  289: 'kept',
#  290: 'sea',
#  291: 'dodo',
#  292: 'whole',
#  293: 'room',
#  294: 'gone',
#  295: 'cook',
#  296: 'mad',
#  297: 'dance',
#  298: 'beginning',
#  299: 'many',
#  300: 'among',
#  301: 'afraid',
#  302: 'every',
#  303: 'finished',
#  304: 'best',
#  305: 'game',
#  306: 'hardly',
#  307: 'deal',
#  308: 'give',
#  309: 'try',
#  310: 'used',
#  311: 'hands',
#  312: '\n      ',
#  313: 'always',
#  314: 'turning',
#  315: 'arm',
#  316: 'pigeon',
#  317: 'baby',
#  318: 'tea',
#  319: 'majesty',
#  320: 'whether',
#  321: 'hurried',
#  322: 'though',
#  323: 'heads',
#  324: 'glad',
#  325: 'ask',
#  326: 'dinah',
#  327: 'hurry',
#  328: 'read',
#  329: 'waited',
#  330: 'minutes',
#  331: 'makes',
#  332: 'growing',
#  333: 'life',
#  334: 'thinking',
#  335: 'nearly',
#  336: 'bill',
#  337: 'keep',
#  338: 'mind',
#  339: 'either',
#  340: 'lessons',
#  341: 'word',
#  342: 'name',
#  343: 'else',
#  344: 'sight',
#  345: 'walked',
#  346: 'alices',
#  347: 'small',
#  348: 'opened',
#  349: 'those',
#  350: 'bottle',
#  351: 'children',
#  352: 'tears',
#  353: 'child',
#  354: 'foot',
#  355: '\n         ',
#  356: 'yourself',
#  357: 'gloves',
#  358: 'fan',
#  359: 'queer',
#  360: 'everything',
#  361: 'offended',
#  362: 'creatures',
#  363: 'explain',
#  364: 'rest',
#  365: 'mean',
#  366: 'mouth',
#  367: 'turn',
#  368: 'repeated',
#  369: 'footman',
#  370: 'remarked',
#  371: 'remark',
#  372: 'soldiers',
#  373: 'witness',
#  374: 'having',
#  375: 'sitting',
#  376: 'own',
#  377: 'coming',
#  378: 'answer',
#  379: 'matter',
#  380: 'hall',
#  381: 'glass',
#  382: 'key',
#  383: 'rate',
#  384: 'few',
#  385: 'waiting',
#  386: 'hold',
#  387: 'leave',
#  388: 'against',
#  389: 'want',
#  390: '\n       ',
#  391: 'pool',
#  392: 'help',
#  393: 'different',
#  394: 'tail',
#  395: 'conversation',
#  396: 'birds',
#  397: 'continued',
#  398: 'believe',
#  399: 'has',
#  400: 'call',
#  401: 'angrily',
#  402: 'shook',
#  403: 'reason',
#  404: 'together',
#  405: 'shouted',
#  406: 'timidly',
#  407: 'serpent',
#  408: 'puzzled',
#  409: 'interrupted',
#  410: 'knave',
#  411: 'join',
#  412: 'feel',
#  413: 'making',
#  414: 'watch',
#  415: 'slowly',
#  416: 'happen',
#  417: 'noticed',
#  418: 'top',
#  419: 'opportunity',
#  420: 'seem',
#  421: 'dry',
#  422: 'fact',
#  423: 'followed',
#  424: 'lying',
#  425: 'work',
#  426: 'ready',
#  427: 'hard',
#  428: 'changed',
#  429: 'mine',
#  430: 'five',
#  431: 'live',
#  432: 'play',
#  433: 'beg',
#  434: 'our',
#  435: 'eagerly',
#  436: 'sit',
#  437: 'party',
#  438: 'meaning',
#  439: 'running',
#  440: 'everybody',
#  441: 'exactly',
#  442: 'nobody',
#  443: 'window',
#  444: 'least',
#  445: 'place',
#  446: 'appeared',
#  447: 'each',
#  448: 'mushroom',
#  449: 'most',
#  450: 'nose',
#  451: 'asleep',
#  452: 'hearts',
#  453: 'twinkle',
#  454: 'gardeners',
#  455: 'moral',
#  456: 'whiting',
#  457: 'sister',
#  458: 'book',
#  459: 'world',
#  460: 'deep',
#  461: 'somebody',
#  462: 'fall',
#  463: 'listen',
#  464: 'manage',
#  465: 'begun',
#  466: 'dream',
#  467: 'middle',
#  468: 'wondering',
#  469: 'golden',
#  470: 'open',
#  471: 'larger',
#  472: 'bright',
#  473: 'happened',
#  474: 'neck',
#  475: 'drink',
#  476: 'feeling',
#  477: 'generally',
#  478: 'eye',
#  479: 'surprised',
#  480: 'shoes',
#  481: 'myself',
#  482: 'kind',
#  483: 'nonsense',
#  484: 'distance',
#  485: 'sir',
#  486: 'hair',
#  487: 'goes',
#  488: 'repeat',
#  489: 'learn',
#  490: 'frightened',
#  491: 'chin',
#  492: 'william',
#  493: 'history',
#  494: 'fetch',
#  495: 'lory',
#  496: 'trial',
#  497: 'story',
#  498: 'others',
#  499: 'stood',
#  500: 'grown',
#  501: 'business',
#  502: 'wood',
#  503: 'trees',
#  504: 'draw',
#  505: 'silent',
#  506: 'cheshire',
#  507: 'pig',
#  508: 'pleased',
#  509: 'song',
#  510: 'queens',
#  511: 'hedgehog',
#  512: 'lobsters',
#  513: 'soooop',
#  514: 'slates',
#  515: 'tired',
#  516: 'stupid',
#  517: 'trouble',
#  518: 'late',
#  519: 'fell',
#  520: 'four',
#  521: 'nice',
#  522: 'written',
#  523: 'leaves',
#  524: 'jumped',
#  525: 'roof',
#  526: 'inches',
#  527: 'marked',
#  528: 'forgotten',
#  529: 'almost',
#  530: 'ten',
#  531: 'croquet',
#  532: 'english',
#  533: 'sha',
#  534: '\n           ',
#  535: 'stop',
#  536: 'himself',
#  537: 'times',
#  538: 'seven',
#  539: 'grin',
#  540: 'understand',
#  541: 'sentence',
#  542: 'pardon',
#  543: 'trembling',
#  544: 'subject',
#  545: 'politely',
#  546: 'melancholy',
#  547: 'liked',
#  548: 'chorus',
#  549: '\n        ',
#  550: '\n          ',
#  551: 'executed',
#  552: 'broken',
#  553: 'full',
#  554: 'write',
#  555: 'loud',
#  556: 'sharp',
#  557: 'puppy',
#  558: 'arms',
#  559: 'father',
#  560: 'stand',
#  561: 'youth',
#  562: 'sleep',
#  563: 'sneezing',
#  564: 'between',
#  565: 'told',
#  566: 'pepper',
#  567: 'ear',
#  568: 'wow',
#  569: 'dreadfully',
#  570: 'sing',
#  571: 'exclaimed',
#  572: 'breadandbutter',
#  573: 'lobster',
#  574: 'tarts',
#  575: 'evidence',
#  576: 'hot',
#  577: 'sleepy',
#  578: 'across',
#  579: 'curiosity',
#  580: 'passed',
#  581: 'home',
#  582: 'likely',
#  583: 'aloud',
#  584: 'walk',
#  585: 'new',
#  586: 'asking',
#  587: 'sometimes',
#  588: 'walking',
#  589: 'ears',
#  590: 'sadly',
#  591: 'along',
#  592: 'shut',
#  593: 'cut',
#  594: 'finger',
#  595: 'nervous',
#  596: 'altogether',
#  597: 'fancy',
#  598: 'remembered',
#  599: 'happens',
#  600: 'pair',
#  601: 'nine',
#  602: 'until',
#  603: 'kid',
#  604: 'dropped',
#  605: 'usual',
#  606: 'morning',
#  607: 'ah',
#  608: 'lets',
#  609: 'wrong',
#  610: 'sounded',
#  611: 'strange',
#  612: 'seems',
#  613: 'stay',
#  614: 'sudden',
#  615: 'case',
#  616: 'number',
#  617: 'swam',
#  618: 'nearer',
#  619: 'speaking',
#  620: 'animals',
#  621: 'shrill',
#  622: 'angry',
#  623: 'crowded',
#  624: 'important',
#  625: 'notice',
#  626: 'prizes',
#  627: 'pocket',
#  628: 'dare',
#  629: 'confusion',
#  630: 'reply',
#  631: 'finish',
#  632: 'impatiently',
#  633: 'sighed',
#  634: 'temper',
#  635: 'young',
#  636: 'moved',
#  637: 'swim',
#  638: 'doing',
#  639: 'direction',
#  640: 'interesting',
#  641: 'chimney',
#  642: 'become',
#  643: 'taking',
#  644: 'shriek',
#  645: 'drew',
#  646: 'instantly',
#  647: 'surprise',
#  648: 'lizard',
#  649: 'height',
#  650: 'quietly',
#  651: 'hookah',
#  652: 'man',
#  653: 'often',
#  654: 'eggs',
#  655: 'tree',
#  656: 'meant',
#  657: 'waving',
#  658: 'treacle',
#  659: 'piece',
#  660: 'faces',
#  661: 'procession',
#  662: 'rule',
#  663: 'pack',
#  664: 'knee',
#  665: 'whispered',
#  666: 'flamingo',
#  667: 'executioner',
#  668: 'tis',
#  669: 'school',
#  670: 'adventures',
#  671: 'jurymen',
#  672: 'twice',
#  673: 'simple',
#  674: 'pictures',
#  675: 'worth',
#  676: 'natural',
#  677: 'sides',
#  678: 'fear',
#  679: 'managed',
#  680: 'true',
#  681: 'fallen',
#  682: 'earth',
#  683: 'several',
#  684: 'sound',
#  685: 'girl',
#  686: 'miss',
#  687: 'bats',
#  688: 'passage',
#  689: 'except',
#  690: 'tiny',
#  691: 'alas',
#  692: 'second',
#  693: 'led',
#  694: 'shoulders',
#  695: 'paper',
#  696: 'taught',
#  697: 'deeply',
#  698: 'ventured',
#  699: 'reach',
#  700: 'sharply',
#  701: 'severely',
#  702: 'box',
#  703: 'person',
#  704: 'care',
#  705: 'boots',
#  706: 'savage',
#  707: 'violently',
#  708: 'today',
#  709: 'age',
#  710: 'mabel',
#  711: 'besides',
#  712: 'puzzling',
#  713: 'twelve',
#  714: 'capital',
#  715: 'alone',
#  716: 'rabbits',
#  717: 'shrinking',
#  718: 'escape',
#  719: 'water',
#  720: 'digging',
#  721: 'french',
#  722: 'paws',
#  723: 'dogs',
#  724: 'says',
#  725: 'pale',
#  726: 'duck',
#  727: 'uncomfortable',
#  728: 'argument',
#  729: 'wanted',
#  730: 'frowning',
#  731: 'means',
#  732: 'solemnly',
#  733: 'pointing',
#  734: 'confused',
#  735: 'thimble',
#  736: 'short',
#  737: 'bowed',
#  738: '\n            ',
#  739: 'judge',
#  740: 'breath',
#  741: 'tongue',
#  742: 'since',
#  743: 'vanished',
#  744: 'mary',
#  745: 'ann',
#  746: 'run',
#  747: 'chance',
#  748: 'ordered',
#  749: 'answered',
#  750: 'outside',
#  751: 'yer',
#  752: 'honour',
#  753: 'sounds',
#  754: 'hearing',
#  755: 'fellow',
#  756: 'thank',
#  757: 'dead',
#  758: 'doubt',
#  759: 'lay',
#  760: 'crowd',
#  761: 'held',
#  762: 'guineapigs',
#  763: 'plan',
#  764: 'difficulty',
#  765: 'stick',
#  766: 'grass',
#  767: 'perfectly',
#  768: 'none',
#  769: 'stuff',
#  770: 'decidedly',
#  771: 'thoughtfully',
#  772: 'green',
#  773: 'screamed',
#  774: 'indignantly',
#  775: 'taken',
#  776: 'sky',
#  777: 'lives',
#  778: 'otherwise',
#  779: 'ground',
#  780: 'dish',
#  781: 'kitchen',
#  782: 'jumping',
#  783: 'carried',
#  784: 'hours',
#  785: 'busily',
#  786: 'beat',
#  787: 'verse',
#  788: 'creature',
#  789: 'grunted',
#  790: 'less',
#  791: 'fast',
#  792: 'crumbs',
#  793: 'shoulder',
#  794: 'twinkling',
#  795: 'sigh',
#  796: 'bottom',
#  797: 'begins',
#  798: 'rosetree',
#  799: 'consider',
#  800: 'arches',
#  801: 'players',
#  802: 'sobs',
#  803: 'porpoise',
#  804: 'beauootiful',
#  805: 'trials',
#  806: 'jurybox',
#  807: 'jurors',
#  808: 'writing',
#  809: 'officers',
#  810: 'suppressed',
#  811: 'verses',
#  812: 'days',
#  813: 'peeped',
#  814: 'reading',
#  815: 'considering',
#  816: 'nor',
#  817: 'dark',
#  818: 'filled',
#  819: 'stairs',
#  820: 'miles',
#  821: 'somewhere',
#  822: 'knowledge',
#  823: 'grand',
#  824: 'funny',
#  825: 'listening',
#  826: 'shell',
#  827: 'hope',
#  828: 'mice',
#  829: 'catch',
#  830: 'bat',
#  831: 'hurt',
#  832: 'lost',
#  833: 'corner',
#  834: 'whiskers',
#  835: 'longer',
#  836: 'hanging',
#  837: 'delight',
#  838: 'telescope',
#  839: 'outoftheway',
#  840: 'impossible',
#  841: 'hoping',
#  842: 'rules',
#  843: 'poison',
#  844: 'certain',
#  845: 'later',
#  846: 'finding',
#  847: 'further',
#  848: 'candle',
#  849: 'decided',
#  850: 'possibly',
#  851: 'legs',
#  852: 'bring',
#  853: 'fond',
#  854: 'cake',
#  855: 'smaller',
#  856: 'holding',
#  857: 'remained',
#  858: 'expecting',
#  859: 'dull',
#  860: 'opening',
#  861: 'dears',
#  862: 'directions',
#  863: 'love',
#  864: 'cry',
#  865: 'pattering',
#  866: 'muttering',
#  867: 'timid',
#  868: 'yesterday',
#  869: 'night',
#  870: 'thats',
#  871: 'sorts',
#  872: 'doth',
#  873: 'crossed',
#  874: 'hoarse',
#  875: 'spread',
#  876: 'gently',
#  877: 'putting',
#  878: 'guess',
#  879: 'cause',
#  880: 'worse',
#  881: 'slipped',
#  882: 'general',
#  883: 'notion',
#  884: 'show',
#  885: 'fire',
#  886: 'throw',
#  887: 'passion',
#  888: 'shore',
#  889: 'eaglet',
#  890: 'fur',
#  891: 'sulky',
#  892: 'allow',
#  893: 'crown',
#  894: 'move',
#  895: 'pressed',
#  896: 'handed',
#  897: 'gravely',
#  898: 'speech',
#  899: 'cheered',
#  900: 'grave',
#  901: 'solemn',
#  902: 'noise',
#  903: 'choked',
#  904: 'whisper',
#  905: 'sad',
#  906: 'tale',
#  907: 'sighing',
#  908: 'fury',
#  909: 'met',
#  910: 'attending',
#  911: 'pleaded',
#  912: 'easily',
#  913: 'joined',
#  914: 'pity',
#  915: 'crab',
#  916: 'particular',
#  917: 'venture',
#  918: 'carefully',
#  919: 'remarking',
#  920: 'suit',
#  921: 'mentioned',
#  922: 'guessed',
#  923: 'hunting',
#  924: 'mistake',
#  925: 'plate',
#  926: 'knocking',
#  927: 'real',
#  928: 'floor',
#  929: 'effect',
#  930: 'elbow',
#  931: 'whatever',
#  932: 'stopped',
#  933: 'forgetting',
#  934: 'bills',
#  935: 'em',
#  936: 'below',
#  937: 'master',
#  938: 'kick',
#  939: 'above',
#  940: 'sense',
#  941: 'moving',
#  942: 'cakes',
#  943: 'paw',
#  944: 'hungry',
#  945: 'picked',
#  946: 'edge',
#  947: 'immediately',
#  948: 'folded',
#  949: 'confusing',
#  950: 'brought',
#  951: 'remarks',
#  952: 'pray',
#  953: 'questions',
#  954: 'free',
#  955: 'shaking',
#  956: 'succeeded',
#  957: 'serpents',
#  958: 'girls',
#  959: 'tasted',
#  960: 'yours',
#  961: 'settled',
#  962: 'pieces',
#  963: 'nibbling',
#  964: 'bringing',
#  965: 'livery',
#  966: 'considered',
#  967: 'loudly',
#  968: 'letter',
#  969: 'order',
#  970: 'staring',
#  971: 'howling',
#  972: 'instance',
#  973: 'repeating',
#  974: 'nursing',
#  975: 'courage',
#  976: 'grinned',
#  977: 'growl',
#  978: 'faster',
#  979: 'advantage',
#  980: 'tossing',
#  981: 'caught',
#  982: 'proper',
#  983: 'sobbing',
#  984: 'instead',
#  985: 'civil',
#  986: 'fun',
#  987: 'breathe',
#  988: 'butter',
#  989: 'oclock',
#  990: 'cautiously',
#  991: 'music',
#  992: 'fly',
#  993: 'lady',
#  994: 'lived',
#  995: 'upset',
#  996: 'roses',
#  997: 'beheaded',
#  998: 'watching',
#  999: 'checked',
#  1000: 'themselves',
#  ...}

# %%
for i in sequences[0]:
    print(f'{i} : {tokenizer.index_word[i]}')
# Out:
# 11 : alice
# 12 : was
# 298 : beginning
# 3 : to
# 102 : get
# 29 : very
# 515 : tired
# 7 : of
# 375 : sitting
# 79 : by
# 16 : her
# 457 : sister
# 19 : on
# 1 : the
# 1454 : bank
# 2 : and
# 7 : of
# 374 : having
# 134 : nothing
# 3 : to
# 31 : do
# 141 : once
# 59 : or
# 672 : twice
# 5 : she
# 20 : had

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('alice', 9985),
#              ('was', 9544),
#              ('beginning', 315),
#              ('to', 18718),
#              ('get', 1175),
#              ('very', 3724),
#              ('tired', 163),
#              ('of', 13155),
#              ('sitting', 243),
#              ('by', 1440),
#              ('her', 6417),
#              ('sister', 194),
#              ('on', 5005),
#              ('the', 42141),
#              ('bank', 41),
#              ('and', 21857),
#              ('having', 252),
#              ('nothing', 877),
#              ('do', 3635),
#              ('once', 828),
#              ('or', 1973),
#              ('twice', 128),
#              ('she', 14117),
#              ('had', 4836),
#              ('peeped', 78),
#              ('into', 1742),
#              ('book', 182),
#              ('reading', 78),
#              ('but', 4264),
#              ('it', 13884),
#              ('no', 2262),
#              ('pictures', 104),
#              ('conversations', 52),
#              ('in', 9454),
#              ('what', 3666),
#              ('is', 2834),
#              ('use', 468),
#              ('a', 16164),
#              ('thought', 1924),
#              ('without', 650),
#              ('so', 3900),
#              ('considering', 78),
#              ('own', 243),
#              ('mind', 260),
#              ('as', 6812),
#              ('well', 1560),
#              ('could', 2236),
#              ('for', 3978),
#              ('hot', 130),
#              ('day', 650),
#              ('made', 780),
#              ('feel', 208),
#              ('sleepy', 130),
#              ('stupid', 156),
#              ('whether', 286),
#              ('pleasure', 43),
#              ('making', 208),
#              ('daisychain', 26),
#              ('would', 2496),
#              ('be', 3796),
#              ('worth', 104),
#              ('trouble', 156),
#              ('getting', 572),
#              ('up', 2548),
#              ('picking', 52),
#              ('daisies', 26),
#              ('when', 2054),
#              ('suddenly', 338),
#              ('white', 780),
#              ('rabbit', 1092),
#              ('with', 4705),
#              ('pink', 26),
#              ('eyes', 702),
#              ('ran', 416),
#              ('close', 338),
#              ('there', 2574),
#              ('remarkable', 52),
#              ('that', 7982),
#              ('nor', 78),
#              ('did', 1976),
#              ('think', 1378),
#              ('much', 1326),
#              ('out', 2938),
#              ('way', 1352),
#              ('hear', 364),
#              ('say', 1300),
#              ('itself', 364),
#              ('oh', 988),
#              ('dear', 754),
#              ('i', 12948),
#              ('shall', 650),
#              ('late', 156),
#              ('over', 1040),
#              ('afterwards', 52),
#              ('occurred', 52),
#              ('ought', 364),
#              ('have', 2288),
#              ('wondered', 26),
#              ('at', 5434),
#              ('this', 3484),
#              ('time', 1768),
#              ('all', 4641),
#              ('seemed', 702),
#              ('quite', 1430),
#              ('natural', 104),
#              ('actually', 26),
#              ('took', 624),
#              ('watch', 208),
#              ('its', 2886),
#              ('waistcoatpocket', 52),
#              ('looked', 1170),
#              ('then', 2340),
#              ('hurried', 286),
#              ('started', 52),
#              ('feet', 494),
#              ('flashed', 26),
#              ('across', 130),
#              ('never', 1170),
#              ('before', 962),
#              ('seen', 364),
#              ('either', 260),
#              ('take', 546),
#              ('burning', 26),
#              ('curiosity', 130),
#              ('field', 26),
#              ('after', 1092),
#              ('fortunately', 26),
#              ('just', 1326),
#              ('see', 1716),
#              ('pop', 26),
#              ('down', 2600),
#              ('large', 858),
#              ('rabbithole', 52),
#              ('under', 416),
#              ('hedge', 52),
#              ('another', 572),
#              ('moment', 754),
#              ('went', 2158),
#              ('how', 1664),
#              ('world', 182),
#              ('again', 2132),
#              ('straight', 52),
#              ('like', 2210),
#              ('tunnel', 26),
#              ('some', 1326),
#              ('dipped', 52),
#              ('not', 3770),
#              ('about', 2444),
#              ('stopping', 26),
#              ('herself', 2158),
#              ('found', 832),
#              ('falling', 52),
#              ('deep', 182),
#              ('fell', 156),
#              ('slowly', 208),
#              ('plenty', 52),
#              ('look', 728),
#              ('wonder', 468),
#              ('going', 702),
#              ('happen', 208),
#              ('next', 780),
#              ('first', 1274),
#              ('tried', 494),
#              ('make', 676),
#              ('coming', 234),
#              ('too', 676),
#              ('dark', 78),
#              ('anything', 494),
#              ('sides', 104),
#              ('noticed', 208),
#              ('they', 3874),
#              ('were', 2288),
#              ('filled', 78),
#              ('cupboards', 52),
#              ('bookshelves', 26),
#              ('here', 1248),
#              ('saw', 364),
#              ('maps', 26),
#              ('hung', 26),
#              ('upon', 676),
#              ('pegs', 26),
#              ('jar', 52),
#              ('from', 910),
#              ('one', 2626),
#              ('shelves', 26),
#              ('passed', 130),
#              ('labelled', 26),
#              ('orange', 26),
#              ('marmalade', 26),
#              ('great', 1014),
#              ('disappointment', 26),
#              ('empty', 26),
#              ('drop', 26),
#              ('fear', 104),
#              ('killing', 26),
#              ('somebody', 182),
#              ('managed', 104),
#              ('put', 806),
#              ('past', 26),
#              ('such', 1066),
#              ('fall', 182),
#              ('tumbling', 52),
#              ('stairs', 78),
#              ('brave', 26),
#              ('ll', 494),
#              ('me', 1768),
#              ('home', 130),
#              ('why', 1014),
#              ('nt', 5590),
#              ('even', 494),
#              ('if', 2444),
#              ('off', 1898),
#              ('top', 208),
#              ('house', 468),
#              ('which', 1274),
#              ('likely', 130),
#              ('true', 104),
#              ('come', 1170),
#              ('an', 1482),
#              ('end', 442),
#              ('many', 312),
#              ('miles', 78),
#              ('ve', 1092),
#              ('fallen', 104),
#              ('said', 12012),
#              ('aloud', 130),
#              ('must', 1144),
#              ('somewhere', 78),
#              ('near', 390),
#              ('centre', 26),
#              ('earth', 104),
#              ('let', 442),
#              ('four', 156),
#              ('thousand', 52),
#              ('you', 10504),
#              ('learnt', 52),
#              ('several', 104),
#              ('things', 728),
#              ('sort', 520),
#              ('lessons', 260),
#              ('schoolroom', 26),
#              ('though', 286),
#              ('good', 624),
#              ('opportunity', 208),
#              ('showing', 52),
#              ('knowledge', 78),
#              ('listen', 182),
#              ('still', 338),
#              ('practice', 26),
#              ('yes', 338),
#              ('s', 1846),
#              ('right', 806),
#              ('distancebut', 26),
#              ('latitude', 52),
#              ('longitude', 52),
#              ('got', 1170),
#              ('idea', 390),
#              ('nice', 156),
#              ('grand', 78),
#              ('words', 546),
#              ('presently', 52),
#              ('began', 1508),
#              ('through', 364),
#              ('funny', 78),
#              ('seem', 208),
#              ('among', 312),
#              ('people', 338),
#              ('walk', 130),
#              ('their', 1337),
#              ('heads', 286),
#              ('downward', 26),
#              ('antipathies', 26),
#              ('rather', 650),
#              ('glad', 286),
#              ('listening', 78),
#              ('sound', 104),
#              ('word', 260),
#              ('ask', 286),
#              ('them', 2184),
#              ('name', 260),
#              ('country', 26),
#              ('know', 2210),
#              ('please', 494),
#              ('maam', 26),
#              ('new', 130),
#              ('zealand', 26),
#              ('australia', 26),
#              ('curtsey', 26),
#              ('spokefancy', 26),
#              ('curtseying', 26),
#              ('re', 936),
#              ('air', 364),
#              ('manage', 182),
#              ('ignorant', 26),
#              ('little', 3302),
#              ('girl', 104),
#              ('shell', 78),
#              ('asking', 130),
#              ('perhaps', 442),
#              ('written', 156),
#              ('else', 260),
#              ('soon', 650),
#              ('talking', 442),
#              ('dinahll', 52),
#              ('miss', 104),
#              ('tonight', 26),
#              ('should', 832),
#              ('dinah', 286),
#              ('cat', 910),
#              ('hope', 78),
#              ('remember', 364),
#              ('saucer', 26),
#              ('milk', 26),
#              ('teatime', 52),
#              ('my', 1508),
#              ('wish', 546),
#              ('are', 1378),
#              ('mice', 78),
#              ('m', 1534),
#              ('afraid', 312),
#              ('might', 728),
#              ('catch', 78),
#              ('bat', 78),
#              ('mouse', 988),
#              ('cats', 390),
#              ('eat', 468),
#              ('bats', 104),
#              ('saying', 390),
#              ('dreamy', 26),
#              ('sometimes', 130),
#              ('answer', 234),
#              ('question', 442),
#              ('matter', 234),
#              ('felt', 598),
#              ('dozing', 26),
#              ('begun', 182),
#              ('dream', 182),
#              ('walking', 130),
#              ('hand', 520),
#              ('earnestly', 52),
#              ('now', 1482),
#              ('tell', 806),
#              ('truth', 26),
#              ('ever', 546),
#              ('thump', 52),
#              ('came', 1040),
#              ('heap', 26),
#              ('sticks', 26),
#              ('dry', 208),
#              ('leaves', 156),
#              ('bit', 416),
#              ('hurt', 78),
#              ('jumped', 156),
#              ('overhead', 26),
#              ('long', 806),
#              ('passage', 104),
#              ('sight', 260),
#              ('hurrying', 26),
#              ('lost', 78),
#              ('away', 650),
#              ('wind', 52),
#              ('turned', 416),
#              ('corner', 78),
#              ('ears', 130),
#              ('whiskers', 78),
#              ('behind', 338),
#              ('longer', 78),
#              ('low', 364),
#              ('hall', 234),
#              ('lit', 26),
#              ('row', 52),
#              ('lamps', 26),
#              ('hanging', 78),
#              ('roof', 156),
#              ('doors', 52),
#              ('round', 1066),
#              ('locked', 26),
#              ('been', 988),
#              ('side', 442),
#              ('other', 1014),
#              ('trying', 364),
#              ('every', 312),
#              ('door', 754),
#              ('walked', 260),
#              ('sadly', 130),
#              ('middle', 182),
#              ('wondering', 182),
#              ('threelegged', 52),
#              ('table', 468),
#              ('solid', 26),
#              ('glass', 234),
#              ('except', 104),
#              ('tiny', 104),
#              ('golden', 182),
#              ('key', 234),
#              ('alices', 260),
#              ('belong', 26),
#              ('alas', 104),
#              ('locks', 52),
#              ('small', 260),
#              ('any', 1014),
#              ('rate', 234),
#              ('open', 182),
#              ('however', 520),
#              ('second', 104),
#              ('curtain', 26),
#              ('fifteen', 26),
#              ('inches', 156),
#              ('high', 416),
#              ('lock', 26),
#              ('delight', 78),
#              ('fitted', 26),
#              ('opened', 260),
#              ('led', 104),
#              ('larger', 182),
#              ('than', 624),
#              ('rathole', 26),
#              ('knelt', 26),
#              ('along', 130),
#              ('loveliest', 26),
#              ('garden', 390),
#              ('longed', 52),
#              ('wander', 26),
#              ('those', 260),
#              ('beds', 26),
#              ('bright', 182),
#              ('flowers', 52),
#              ('cool', 52),
#              ('fountains', 52),
#              ('head', 1248),
#              ('doorway', 26),
#              ('go', 1300),
#              ('poor', 702),
#              ('shoulders', 104),
#              ('shut', 130),
#              ('telescope', 78),
#              ('only', 1274),
#              ('knew', 390),
#              ('begin', 338),
#              ('outoftheway', 78),
#              ('happened', 182),
#              ('lately', 26),
#              ('few', 234),
#              ('indeed', 416),
#              ('really', 338),
#              ('impossible', 78),
#              ('waiting', 234),
#              ('back', 988),
#              ('half', 546),
#              ('hoping', 78),
#              ('find', 539),
#              ('rules', 78),
#              ('shutting', 52),
#              ('telescopes', 26),
#              ('bottle', 260),
#              ('certainly', 364),
#              ('neck', 182),
#              ('paper', 104),
#              ('label', 52),
#              ('drink', 182),
#              ('beautifully', 52),
#              ('printed', 26),
#              ('letters', 26),
#              ('wise', 52),
#              ('hurry', 286),
#              ('ill', 858),
#              ('marked', 156),
#              ('poison', 78),
#              ('read', 286),
#              ('histories', 26),
#              ('children', 260),
#              ('who', 1586),
#              ('burnt', 26),
#              ('eaten', 26),
#              ('wild', 52),
#              ('beasts', 52),
#              ('unpleasant', 52),
#              ('because', 390),
#              ('simple', 113),
#              ('friends', 52),
#              ('taught', 104),
#              ('redhot', 26),
#              ('poker', 26),
#              ('will', 806),
#              ('burn', 52),
#              ('hold', 234),
#              ('cut', 130),
#              ('your', 1612),
#              ('finger', 130),
#              ('deeply', 104),
#              ('knife', 52),
#              ('usually', 52),
#              ('bleeds', 26),
#              ('forgotten', 156),
#              ('almost', 156),
#              ('certain', 78),
#              ('disagree', 26),
#              ('sooner', 52),
#              ('later', 78),
#              ('ventured', 104),
#              ('taste', 52),
#              ('finding', 78),
#              ('fact', 208),
#              ('mixed', 52),
#              ('flavour', 26),
#              ('cherrytart', 26),
#              ('custard', 26),
#              ('pineapple', 26),
#              ('roast', 26),
#              ('turkey', 26),
#              ('toffee', 26),
#              ('buttered', 26),
#              ('toast', 26),
#              ('finished', 312),
#              ('\n                          \n\n                        \n\n                          \n',
#               52),
#              ('curious', 494),
#              ('feeling', 182),
#              ('ten', 156),
#              ('face', 364),
#              ('brightened', 52),
#              ('size', 338),
#              ('lovely', 52),
#              ('waited', 286),
#              ('minutes', 286),
#              ('shrink', 26),
#              ('further', 78),
#              ('nervous', 130),
#              ('altogether', 130),
#              ('candle', 78),
#              ('fancy', 130),
#              ('flame', 26),
#              ('blown', 26),
#              ('thing', 1274),
#              ('while', 624),
#              ('more', 1248),
#              ('decided', 78),
#              ('possibly', 78),
#              ('reach', 104),
#              ('plainly', 26),
#              ('best', 312),
#              ('climb', 26),
#              ('legs', 78),
#              ('slippery', 26),
#              ('sat', 442),
#              ('cried', 520),
#              ('crying', 52),
#              ('sharply', 104),
#              ('advise', 26),
#              ('leave', 234),
#              ('minute', 546),
#              ('generally', 182),
#              ('gave', 390),
#              ('advice', 26),
#              ('seldom', 26),
#              ('followed', 208),
#              ('scolded', 26),
#              ('severely', 104),
#              ('bring', 78),
#              ('tears', 260),
#              ('remembered', 130),
#              ('box', 104),
#              ('cheated', 26),
#              ('game', 312),
#              ('croquet', 156),
#              ('playing', 52),
#              ('against', 234),
#              ('child', 260),
#              ('fond', 78),
#              ('pretending', 26),
#              ('two', 1014),
#              ('pretend', 26),
#              ('hardly', 312),
#              ('enough', 442),
#              ('left', 364),
#              ('respectable', 26),
#              ('person', 104),
#              ('eye', 182),
#              ('lying', 208),
#              ('cake', 78),
#              ('currants', 26),
#              ('makes', 286),
#              ('grow', 338),
#              ('can', 910),
#              ('smaller', 78),
#              ('creep', 26),
#              ('care', 104),
#              ('happens', 130),
#              ('ate', 26),
#              ('anxiously', 364),
#              ('holding', 78),
#              ('growing', 286),
#              ('surprised', 182),
#              ('remained', 78),
#              ('same', 624),
#              ('sure', 624),
#              ('eats', 26),
#              ('expecting', 78),
#              ('dull', 78),
#              ('life', 286),
#              ('common', 26),
#              ('set', 364),
#              ('work', 208),
#              ('\n\n                          \n\n                        \n\n                          \n',
#               26),
#              ('curiouser', 52),
#              ('forgot', 52),
#              ('speak', 364),
#              ('english', 156),
#              ('opening', 78),
#              ('largest', 26),
#              ('goodbye', 26),
#              ('far', 338),
#              ('shoes', 182),
#              ('stockings', 26),
#              ('dears', 78),
#              ('sha', 156),
#              ('able', 26),
#              ('deal', 312),
#              ('myself', 182),
#              ('canbut', 26),
#              ('kind', 182),
#              ('wo', 624),
#              ('want', 234),
#              ('give', 312),
#              ('pair', 130),
#              ('boots', 104),
#              ('christmas', 26),
#              ('planning', 26),
#              ('carrier', 26),
#              ('sending', 52),
#              ('presents', 52),
#              ('ones', 52),
#              ('odd', 26),
#              ('directions', 78),
#              ('\n     ', 468),
#              ('foot', 260),
#              ('esq', 26),
#              ('\n       ', 234),
#              ('hearthrug', 26),
#              ('\n         ', 260),
#              ('fender', 26),
#              ('\n           ', 156),
#              ('love', 78),
#              ('nonsense', 182),
#              ('struck', 52),
#              ('nine', 130),
#              ('hopeless', 26),
#              ('cry', 78),
#              ('ashamed', 52),
#              ('yourself', 260),
#              ('stop', 156),
#              ('shedding', 26),
#              ('gallons', 26),
#              ('until', 130),
#              ('pool', 234),
#              ('reaching', 26),
#              ('heard', 780),
#              ('pattering', 78),
#              ('distance', 182),
#              ('hastily', 416),
#              ('dried', 26),
#              ('returning', 26),
#              ('splendidly', 26),
#              ('dressed', 26),
#              ('kid', 130),
#              ('gloves', 260),
#              ('fan', 260),
#              ('he', 3224),
#              ('trotting', 52),
#              ('muttering', 78),
#              ('himself', 156),
#              ('duchess', 1014),
#              ('savage', 104),
#              ('kept', 338),
#              ('desperate', 26),
#              ('ready', 208),
#              ('help', 234),
#              ('timid', 78),
#              ('voice', 1222),
#              ('sir', 182),
#              ('violently', 104),
#              ('dropped', 130),
#              ('skurried', 26),
#              ('darkness', 26),
#              ('hard', 208),
#              ('fanning', 26),
#              ('queer', 260),
#              ('everything', 260),
#              ('today', 104),
#              ('yesterday', 78),
#              ('usual', 130),
#              ('changed', 208),
#              ('night', 78),
#              ('morning', 130),
#              ('different', 234),
#              ('am', 390),
#              ('ah', 130),
#              ('thats', 78),
#              ('puzzle', 26),
#              ('thinking', 286),
#              ('age', 104),
#              ('ada', 26),
#              ('hair', 182),
#              ('goes', 182),
#              ('ringlets', 52),
#              ('mine', 208),
#              ('does', 650),
#              ('ca', 728),
#              ('mabel', 104),
#              ('sorts', 78),
#              ('knows', 52),
#              ('besides', 104),
#              ('shes', 26),
#              ('andoh', 52),
#              ('puzzling', 104),
#              ('try', 312),
#              ('used', 312),
#              ('times', 156),
#              ('five', 208),
#              ('twelve', 104),
#              ('six', 52),
#              ('thirteen', 26),
#              ('seven', 156),
#              ('isoh', 52),
#              ('twenty', 26),
#              ('multiplication', 26),
#              ('signify', 26),
#              ('lets', 130),
#              ('geography', 26),
#              ('london', 26),
#              ('capital', 104),
#              ('paris', 52),
#              ('rome', 26),
#              ('romeno', 26),
#              ('wrong', 130),
#              ('doth', 78),
#              ('crossed', 78),
#              ('hands', 312),
#              ('lap', 52),
#              ('repeat', 182),
#              ('sounded', 130),
#              ('hoarse', 78),
#              ('strange', 130),
#              ('crocodile', 26),
#              ('\n      ', 312),
#              ('improve', 26),
#              ('his', 2496),
#              ('shining', 26),
#              ('tail', 234),
#              ('pour', 26),
#              ('waters', 26),
#              ('nile', 26),
#              ('scale', 26),
#              ('\n\n     ', 26),
#              ('cheerfully', 26),
#              ('seems', 130),
#              ('grin', 156),
#              ('neatly', 52),
#              ('spread', 78),
#              ('claws', 52),
#              ('welcome', 26),
#              ('fishes', 26),
#              ('gently', 78),
#              ('smiling', 52),
#              ('jaws', 52),
#              ('live', 208),
#              ('poky', 26),
#              ('toys', 26),
#              ('play', 208),
#              ('learn', 182),
#              ('stay', 130),
#              ('putting', 78),
#              ('being', 494),
#              ('till', 546),
#              ('elsebut', 26),
#              ('sudden', 130),
#              ('burst', 26),
#              ('alone', 104),
#              ('rabbits', 104),
#              ('done', 390),
#              ('measure', 26),
#              ('nearly', 286),
#              ('guess', 78),
#              ('shrinking', 104),
#              ('rapidly', 52),
#              ('cause', 78),
#              ('avoid', 26),
#              ('narrow', 52),
#              ('escape', 104),
#              ('frightened', 182),
#              ('change', 364),
#              ('existence', 26),
#              ('speed', 26),
#              ('worse', 78),
#              ('declare', 52),
#              ('bad', 52),
#              ('these', 364),
#              ('slipped', 78),
#              ('splash', 26),
#              ('chin', 182),
#              ('salt', 52),
#              ('water', 104),
#              ('somehow', 26),
#              ('sea', 338),
#              ('case', 130),
#              ('railway', 52),
#              ('seaside', 26),
#              ('general', 78),
#              ('conclusion', 52),
#              ('wherever', 52),
#              ('coast', 26),
#              ('number', 130),
#              ('bathing', 26),
#              ('machines', 26),
#              ('digging', 104),
#              ('sand', 26),
#              ('wooden', 26),
#              ('spades', 26),
#              ('lodging', 26),
#              ('houses', 26),
#              ('station', 26),
#              ('wept', 26),
#              ('swam', 130),
#              ('punished', 26),
#              ('suppose', 364),
#              ('drowned', 26),
#              ('something', 468),
#              ('splashing', 52),
#              ('nearer', 130),
#              ('walrus', 26),
#              ('hippopotamus', 26),
#              ('talk', 364),
#              ('harm', 26),
#              ('o', 52),
#              ('swimming', 52),
#              ('speaking', 130),
#              ('brothers', 26),
#              ('latin', 26),
#              ('grammar', 26),
#              ('mouseof', 26),
#              ('mouseto', 26),
#              ('mousea', 26),
#              ('mouseo', 26),
#              ('inquisitively', 26),
#              ('wink', 52),
#              ('understand', 156),
#              ('daresay', 26),
#              ('french', 104),
#              ('william', 182),
#              ('conqueror', 52),
#              ('history', 182),
#              ('clear', 52),
#              ('notion', 78),
#              ('ago', 52),
#              ('ou', 26),
#              ('est', 26),
#              ('ma', 52),
#              ('chatte', 26),
#              ('sentence', 156),
#              ('lessonbook', 26),
#              ('leap', 26),
#              ('quiver', 26),
#              ('fright', 52),
#              ('beg', 208),
#              ('pardon', 156),
#              ('animals', 130),
#              ('feelings', 52),
#              ('shrill', 130),
#              ('passionate', 26),
#              ('soothing', 26),
#              ('tone', 1040),
#              ('angry', 130),
#              ('yet', 572),
#              ('show', 78),
#              ('our', 208),
#              ('d', 676),
#              ('quiet', 52),
#              ('lazily', 26),
#              ('sits', 26),
#              ('purring', 52),
#              ('nicely', 52),
#              ('fire', 78),
#              ('licking', 26),
#              ('paws', 104),
#              ('washing', 52),
#              ('faceand', 26),
#              ('soft', 26),
#              ('nurseand', 26),
#              ('catching', 52),
#              ('miceoh', 26),
#              ('bristling', 26),
#              ('offended', 260),
#              ('we', 806),
#              ('trembling', 156),
#              ('subject', 156),
#              ('family', 26),
#              ('always', 312),
#              ('hated', 26),
#              ('nasty', 26),
#              ('vulgar', 26),
#              ('conversation', 234),
#              ('youare', 26),
#              ('fondofof', 26),
#              ('dogs', 104),
#              ('eagerly', 208),
#              ('dog', 52),
#              ('brighteyed', 26),
#              ('terrier', 26),
#              ('curly', 26),
#              ('brown', 52),
#              ('fetch', 182),
#              ('throw', 78),
#              ('sit', 208),
#              ('dinner', 52),
#              ('thingsi', 26),
#              ('themand', 52),
#              ('belongs', 52),
#              ('farmer', 26),
#              ('says', 104),
#              ('useful', 52),
#              ('hundred', 26),
#              ('pounds', 26),
#              ('kills', 26),
#              ('rats', 26),
#              ('sorrowful', 52),
#              ('commotion', 26),
#              ('called', 390),
#              ('softly', 26),
#              ('pale', 104),
#              ('passion', 78),
#              ('us', 364),
#              ('shore', 78),
#              ('hate', 26),
#              ('crowded', 130),
#              ('birds', 234),
#              ('duck', 104),
#              ('dodo', 338),
#              ('lory', 182),
#              ('eaglet', 78),
#              ('creatures', 260),
#              ('whole', 338),
#              ('party', 208),
#              ('queerlooking', 26),
#              ('assembled', 52),
#              ('bankthe', 26),
#              ('draggled', 26),
#              ('feathers', 26),
#              ('fur', 78),
#              ('clinging', 26),
#              ('dripping', 26),
#              ('wet', 52),
#              ('cross', 26),
#              ('uncomfortable', 104),
#              ('course', 624),
#              ('consultation', 26),
#              ('familiarly', 26),
#              ('known', 26),
#              ('argument', 104),
#              ('last', 858),
#              ('sulky', 78),
#              ('older', 52),
#              ('better', 364),
#              ('allow', 78),
#              ('knowing', 52),
#              ('old', 494),
#              ('positively', 26),
#              ('refused', 26),
#              ('authority', 52),
#              ('ring', 52),
#              ('fixed', 26),
#              ('cold', 26),
#              ('ahem', 26),
#              ('important', 130),
#              ('driest', 26),
#              ('silence', 364),
#              ('whose', 52),
#              ('favoured', 26),
#              ('pope', 26),
#              ('submitted', 26),
#              ('wanted', 104),
#              ('leaders', 26),
#              ('accustomed', 26),
#              ('usurpation', 26),
#              ('conquest', 26),
#              ('edwin', 52),
#              ('morcar', 52),
#              ('earls', 52),
#              ('mercia', 52),
#              ('northumbria', 52),
#              ('ugh', 52),
#              ('shiver', 26),
#              ('frowning', 104),
#              ('politely', 156),
#              ('proceed', 52),
#              ('declared', 26),
#              ('him', 1066),
#              ('stigand', 26),
#              ('patriotic', 26),
#              ('archbishop', 52),
#              ('canterbury', 26),
#              ('advisable', 52),
#              ...])

# %%
vocabulary_size = len(tokenizer.word_counts)
vocabulary_size
# Out:
# 2727

# %%
import numpy as np

# %%
sequences = np.array(sequences)

# %%
sequences
# Out:
# array([[  11,   12,  298, ...,  672,    5,   20],
#        [  12,  298,    3, ...,    5,   20,  813],
#        [ 298,    3,  102, ...,   20,  813,   66],
#        ...,
#        [   5,   42,  412, ..., 2727, 1455,  812],
#        [  42,  412,   21, ..., 1455,  812, 1456],
#        [ 412,   21,   22, ...,  812, 1456,    1]])

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,LSTM,Embedding, Dropout

# %%
def create_model(vocabulary_size, seq_len):
    model = Sequential()
    model.add(Embedding(vocabulary_size, 25, input_length=seq_len))
    model.add(LSTM(256, return_sequences=True))
    model.add(Dropout(0.1))
    model.add(LSTM(256))
    model.add(Dense(150, activation='relu'))

    model.add(Dense(vocabulary_size, activation='softmax'))
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
   
    model.summary()
    
    return model

# %%
from keras.utils import to_categorical

# %%
sequences
# Out:
# array([[  11,   12,  298, ...,  672,    5,   20],
#        [  12,  298,    3, ...,    5,   20,  813],
#        [ 298,    3,  102, ...,   20,  813,   66],
#        ...,
#        [   5,   42,  412, ..., 2727, 1455,  812],
#        [  42,  412,   21, ..., 1455,  812, 1456],
#        [ 412,   21,   22, ...,  812, 1456,    1]])

# %%
# First 49 words
sequences[:,:-1]
# Out:
# array([[  11,   12,  298, ...,   59,  672,    5],
#        [  12,  298,    3, ...,  672,    5,   20],
#        [ 298,    3,  102, ...,    5,   20,  813],
#        ...,
#        [   5,   42,  412, ...,    1, 2727, 1455],
#        [  42,  412,   21, ..., 2727, 1455,  812],
#        [ 412,   21,   22, ..., 1455,  812, 1456]])

# %%
# last Word
sequences[:,-1]
# Out:
# array([  20,  813,   66, ...,  812, 1456,    1])

# %%
X = sequences[:,:-1]

# %%
y = sequences[:,-1]

# %%
y = to_categorical(y, num_classes=vocabulary_size+1)

# %%
seq_len = X.shape[1]
seq_len
# Out:
# 25

# %%
# define model
model = create_model(vocabulary_size+1, seq_len)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0727 12:37:33.468214 140362715903872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0727 12:37:33.515830 140362715903872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0727 12:37:33.522735 140362715903872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0727 12:37:34.038597 140362715903872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# W0727 12:37:34.053612 140362715903872 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# W0727 12:37:34.436005 140362715903872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0727 12:37:34.466821 140362715903872 deprecation_wrapper.py:119] From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 25, 25)            68200
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 25, 256)           288768
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 25, 256)           0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 256)               525312
# _________________________________________________________________
# dense_1 (Dense)              (None, 150)               38550
# _________________________________________________________________
# dense_2 (Dense)              (None, 2728)              411928
# =================================================================
# Total params: 1,332,758
# Trainable params: 1,332,758
# Non-trainable params: 0
# _________________________________________________________________

# %%
from pickle import dump,load

# %%
# fit model
model.fit(X, y, batch_size=128, epochs=200,verbose=1)
# Out:
# W0727 12:37:34.701425 140362715903872 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/200
# 26905/26905 [==============================] - 34s 1ms/step - loss: 6.2897 - acc: 0.0573
# Epoch 2/200
# 26905/26905 [==============================] - 25s 925us/step - loss: 5.9028 - acc: 0.0618
# Epoch 3/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 5.6746 - acc: 0.0690
# Epoch 4/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 5.5179 - acc: 0.0709
# Epoch 5/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 5.4125 - acc: 0.0757
# Epoch 6/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 5.3283 - acc: 0.0797
# Epoch 7/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 5.2581 - acc: 0.0844
# Epoch 8/200
# 26905/26905 [==============================] - 25s 925us/step - loss: 5.1916 - acc: 0.0879
# Epoch 9/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 5.1320 - acc: 0.0921
# Epoch 10/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 5.0730 - acc: 0.0941
# Epoch 11/200
# 26905/26905 [==============================] - 25s 923us/step - loss: 5.0188 - acc: 0.0967
# Epoch 12/200
# 26905/26905 [==============================] - 25s 921us/step - loss: 4.9670 - acc: 0.1018
# Epoch 13/200
# 26905/26905 [==============================] - 25s 923us/step - loss: 4.9104 - acc: 0.1035
# Epoch 14/200
# 26905/26905 [==============================] - 25s 922us/step - loss: 4.8558 - acc: 0.1084
# Epoch 15/200
# 26905/26905 [==============================] - 26s 959us/step - loss: 4.7986 - acc: 0.1081
# Epoch 16/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 4.7388 - acc: 0.1130
# Epoch 17/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 4.6825 - acc: 0.1146
# Epoch 18/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 4.6270 - acc: 0.1176
# Epoch 19/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 4.5766 - acc: 0.1224
# Epoch 20/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 4.5130 - acc: 0.1265
# Epoch 21/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 4.4489 - acc: 0.1308
# Epoch 22/200
# 26905/26905 [==============================] - 25s 937us/step - loss: 4.3896 - acc: 0.1348
# Epoch 23/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 4.3269 - acc: 0.1396
# Epoch 24/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 4.2698 - acc: 0.1424
# Epoch 25/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 4.2100 - acc: 0.1471
# Epoch 26/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 4.1553 - acc: 0.1477
# Epoch 27/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 4.0984 - acc: 0.1520
# Epoch 28/200
# 26905/26905 [==============================] - 25s 938us/step - loss: 4.0502 - acc: 0.1560
# Epoch 29/200
# 26905/26905 [==============================] - 25s 936us/step - loss: 3.9972 - acc: 0.1607
# Epoch 30/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 3.9448 - acc: 0.1629
# Epoch 31/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 3.9066 - acc: 0.1665
# Epoch 32/200
# 26905/26905 [==============================] - 25s 939us/step - loss: 3.8588 - acc: 0.1697
# Epoch 33/200
# 26905/26905 [==============================] - 25s 938us/step - loss: 3.8151 - acc: 0.1717
# Epoch 34/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 3.7679 - acc: 0.1788
# Epoch 35/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 3.7404 - acc: 0.1812
# Epoch 36/200
# 26905/26905 [==============================] - 25s 938us/step - loss: 3.6930 - acc: 0.1854
# Epoch 37/200
# 26905/26905 [==============================] - 25s 936us/step - loss: 3.6430 - acc: 0.1923
# Epoch 38/200
# 26905/26905 [==============================] - 25s 937us/step - loss: 3.6104 - acc: 0.1938
# Epoch 39/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 3.5686 - acc: 0.1993
# Epoch 40/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 3.5280 - acc: 0.2038
# Epoch 41/200
# 26905/26905 [==============================] - 25s 938us/step - loss: 3.4961 - acc: 0.2075
# Epoch 42/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 3.4597 - acc: 0.2144
# Epoch 43/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 3.4251 - acc: 0.2163
# Epoch 44/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 3.3969 - acc: 0.2233
# Epoch 45/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 3.3595 - acc: 0.2292
# Epoch 46/200
# 26905/26905 [==============================] - 25s 938us/step - loss: 3.3229 - acc: 0.2356
# Epoch 47/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 3.2912 - acc: 0.2398
# Epoch 48/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 3.2588 - acc: 0.2436
# Epoch 49/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 3.2367 - acc: 0.2463
# Epoch 50/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 3.2023 - acc: 0.2495
# Epoch 51/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 3.1701 - acc: 0.2558
# Epoch 52/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 3.1375 - acc: 0.2631
# Epoch 53/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 3.1135 - acc: 0.2627
# Epoch 54/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 3.1166 - acc: 0.2633
# Epoch 55/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 3.0869 - acc: 0.2689
# Epoch 56/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 3.0338 - acc: 0.2817
# Epoch 57/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 3.0037 - acc: 0.2828
# Epoch 58/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 2.9779 - acc: 0.2921
# Epoch 59/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 2.9437 - acc: 0.2946
# Epoch 60/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 2.9166 - acc: 0.3009
# Epoch 61/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 2.8988 - acc: 0.3001
# Epoch 62/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.8675 - acc: 0.3081
# Epoch 63/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.8408 - acc: 0.3106
# Epoch 64/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 2.8220 - acc: 0.3203
# Epoch 65/200
# 26905/26905 [==============================] - 25s 937us/step - loss: 2.7937 - acc: 0.3224
# Epoch 66/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 2.7659 - acc: 0.3261
# Epoch 67/200
# 26905/26905 [==============================] - 25s 937us/step - loss: 2.7467 - acc: 0.3277
# Epoch 68/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 2.7192 - acc: 0.3338
# Epoch 69/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 2.6911 - acc: 0.3401
# Epoch 70/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 2.6711 - acc: 0.3421
# Epoch 71/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 2.6437 - acc: 0.3458
# Epoch 72/200
# 26905/26905 [==============================] - 25s 936us/step - loss: 2.6140 - acc: 0.3518
# Epoch 73/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 2.5901 - acc: 0.3588
# Epoch 74/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 2.5687 - acc: 0.3610
# Epoch 75/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 2.5479 - acc: 0.3653
# Epoch 76/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 2.5219 - acc: 0.3696
# Epoch 77/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 2.4976 - acc: 0.3777
# Epoch 78/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.4651 - acc: 0.3831
# Epoch 79/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 2.4439 - acc: 0.3854
# Epoch 80/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.4138 - acc: 0.3905
# Epoch 81/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 2.3876 - acc: 0.3987
# Epoch 82/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 2.3680 - acc: 0.4038
# Epoch 83/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 2.3425 - acc: 0.4085
# Epoch 84/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 2.3147 - acc: 0.4109
# Epoch 85/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.3008 - acc: 0.4134
# Epoch 86/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 2.2650 - acc: 0.4235
# Epoch 87/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 2.2403 - acc: 0.4270
# Epoch 88/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.2153 - acc: 0.4347
# Epoch 89/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 2.1911 - acc: 0.4361
# Epoch 90/200
# 26905/26905 [==============================] - 25s 936us/step - loss: 2.1632 - acc: 0.4469
# Epoch 91/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 2.1448 - acc: 0.4472
# Epoch 92/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 2.1159 - acc: 0.4522
# Epoch 93/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 2.0919 - acc: 0.4614
# Epoch 94/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 2.0576 - acc: 0.4644
# Epoch 95/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 2.0397 - acc: 0.4700
# Epoch 96/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 2.0103 - acc: 0.4792
# Epoch 97/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 1.9907 - acc: 0.4817
# Epoch 98/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 1.9642 - acc: 0.4862
# Epoch 99/200
# 26905/26905 [==============================] - 25s 918us/step - loss: 1.9323 - acc: 0.4973
# Epoch 100/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 1.9184 - acc: 0.5000
# Epoch 101/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.8968 - acc: 0.5009
# Epoch 102/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 1.8675 - acc: 0.5086
# Epoch 103/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.8386 - acc: 0.5159
# Epoch 104/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 1.8186 - acc: 0.5215
# Epoch 105/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 1.7874 - acc: 0.5280
# Epoch 106/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.7592 - acc: 0.5346
# Epoch 107/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 1.7413 - acc: 0.5393
# Epoch 108/200
# 26905/26905 [==============================] - 25s 924us/step - loss: 1.7109 - acc: 0.5472
# Epoch 109/200
# 26905/26905 [==============================] - 25s 924us/step - loss: 1.6972 - acc: 0.5489
# Epoch 110/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 1.6645 - acc: 0.5615
# Epoch 111/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 1.6416 - acc: 0.5631
# Epoch 112/200
# 26905/26905 [==============================] - 25s 925us/step - loss: 1.6195 - acc: 0.5655
# Epoch 113/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 1.5992 - acc: 0.5716
# Epoch 114/200
# 26905/26905 [==============================] - 25s 933us/step - loss: 1.5644 - acc: 0.5799
# Epoch 115/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 1.5487 - acc: 0.5855
# Epoch 116/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 1.5223 - acc: 0.5925
# Epoch 117/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 1.4989 - acc: 0.5956
# Epoch 118/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 1.4713 - acc: 0.6038
# Epoch 119/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 1.4495 - acc: 0.6093
# Epoch 120/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 1.4290 - acc: 0.6137
# Epoch 121/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.4038 - acc: 0.6184
# Epoch 122/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 1.3880 - acc: 0.6233
# Epoch 123/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 1.3550 - acc: 0.6346
# Epoch 124/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 1.3293 - acc: 0.6388
# Epoch 125/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 1.3142 - acc: 0.6426
# Epoch 126/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 1.2916 - acc: 0.6500
# Epoch 127/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 1.2731 - acc: 0.6520
# Epoch 128/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.2547 - acc: 0.6575
# Epoch 129/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.2215 - acc: 0.6678
# Epoch 130/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.2018 - acc: 0.6733
# Epoch 131/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.1851 - acc: 0.6778
# Epoch 132/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.1701 - acc: 0.6824
# Epoch 133/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 1.1487 - acc: 0.6872
# Epoch 134/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 1.1213 - acc: 0.6917
# Epoch 135/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 1.0962 - acc: 0.7020
# Epoch 136/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 1.0695 - acc: 0.7095
# Epoch 137/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 1.0585 - acc: 0.7086
# Epoch 138/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 1.0280 - acc: 0.7193
# Epoch 139/200
# 26905/26905 [==============================] - 25s 937us/step - loss: 1.0210 - acc: 0.7170
# Epoch 140/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.9998 - acc: 0.7252
# Epoch 141/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.9817 - acc: 0.7308
# Epoch 142/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.9646 - acc: 0.7366
# Epoch 143/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.9540 - acc: 0.7366
# Epoch 144/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 0.9314 - acc: 0.7426
# Epoch 145/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.9104 - acc: 0.7492
# Epoch 146/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.8854 - acc: 0.7584
# Epoch 147/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.8668 - acc: 0.7626
# Epoch 148/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.8477 - acc: 0.7679
# Epoch 149/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.8255 - acc: 0.7722
# Epoch 150/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.8310 - acc: 0.7719
# Epoch 151/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 0.8016 - acc: 0.7773
# Epoch 152/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.7889 - acc: 0.7851
# Epoch 153/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.7832 - acc: 0.7831
# Epoch 154/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.7459 - acc: 0.7951
# Epoch 155/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.7471 - acc: 0.7925
# Epoch 156/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.7156 - acc: 0.8045
# Epoch 157/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.7127 - acc: 0.8029
# Epoch 158/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.7027 - acc: 0.8046
# Epoch 159/200
# 26905/26905 [==============================] - 25s 922us/step - loss: 0.6863 - acc: 0.8095
# Epoch 160/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.6854 - acc: 0.8099
# Epoch 161/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 0.6562 - acc: 0.8196
# Epoch 162/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 0.6463 - acc: 0.8206
# Epoch 163/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.6256 - acc: 0.8275
# Epoch 164/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 0.6140 - acc: 0.8300
# Epoch 165/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.5896 - acc: 0.8398
# Epoch 166/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 0.5902 - acc: 0.8374
# Epoch 167/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 0.5770 - acc: 0.8388
# Epoch 168/200
# 26905/26905 [==============================] - 25s 934us/step - loss: 0.5878 - acc: 0.8374
# Epoch 169/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.5708 - acc: 0.8404
# Epoch 170/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.5811 - acc: 0.8356
# Epoch 171/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.5581 - acc: 0.8441
# Epoch 172/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 0.5159 - acc: 0.8605
# Epoch 173/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.5053 - acc: 0.8626
# Epoch 174/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.5161 - acc: 0.8569
# Epoch 175/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.4934 - acc: 0.8656
# Epoch 176/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.4788 - acc: 0.8720
# Epoch 177/200
# 26905/26905 [==============================] - 25s 935us/step - loss: 0.4902 - acc: 0.8625
# Epoch 178/200
# 26905/26905 [==============================] - 25s 925us/step - loss: 0.4752 - acc: 0.8652
# Epoch 179/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.4631 - acc: 0.8711
# Epoch 180/200
# 26905/26905 [==============================] - 25s 932us/step - loss: 0.4591 - acc: 0.8731
# Epoch 181/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.4514 - acc: 0.8748
# Epoch 182/200
# 26905/26905 [==============================] - 25s 930us/step - loss: 0.4522 - acc: 0.8731
# Epoch 183/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.4315 - acc: 0.8824
# Epoch 184/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.4203 - acc: 0.8857
# Epoch 185/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.4290 - acc: 0.8808
# Epoch 186/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.4037 - acc: 0.8906
# Epoch 187/200
# 26905/26905 [==============================] - 25s 931us/step - loss: 0.3951 - acc: 0.8915
# Epoch 188/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.3866 - acc: 0.8942
# Epoch 189/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.3836 - acc: 0.8941
# Epoch 190/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.3824 - acc: 0.8957
# Epoch 191/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.3771 - acc: 0.8964
# Epoch 192/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.3737 - acc: 0.8966
# Epoch 193/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.3498 - acc: 0.9063
# Epoch 194/200
# 26905/26905 [==============================] - 25s 929us/step - loss: 0.3590 - acc: 0.9011
# Epoch 195/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.3650 - acc: 0.8979
# Epoch 196/200
# 26905/26905 [==============================] - 25s 928us/step - loss: 0.3584 - acc: 0.8986
# Epoch 197/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.3497 - acc: 0.9029
# Epoch 198/200
# 26905/26905 [==============================] - 25s 926us/step - loss: 0.3339 - acc: 0.9088
# Epoch 199/200
# 26905/26905 [==============================] - 25s 925us/step - loss: 0.3438 - acc: 0.9032
# Epoch 200/200
# 26905/26905 [==============================] - 25s 927us/step - loss: 0.3398 - acc: 0.9063

# %%
# save the model to file
model.save('epochBIG.h5')
# save the tokenizer
dump(tokenizer, open('epochBIG', 'wb'))

# %%
from random import randint
from pickle import load
from keras.models import load_model
from keras.preprocessing.sequence import pad_sequences

# %%
def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''
    
    # Final Output
    output_text = []
    
    # Intial Seed Sequence
    input_text = seed_text
    
    print("Seed text is: ", input_text)
    print('\n')
    
    # Create num_gen_words
    for i in range(num_gen_words):
        
        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]
        
        # Pad sequences to our trained rate (50 words in the video)
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')
        
        # Predict Class Probabilities for each word
        pred_word_ind = model.predict_classes(pad_encoded, verbose=0)[0]
        
        # Grab word
        pred_word = tokenizer.index_word[pred_word_ind] 
        
        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word
        
        output_text.append(pred_word)
        
    # Make it look like a sentence.
    return ' '.join(output_text)

# %%
text_sequences[0]
# Out:
# ['alice',
#  'was',
#  'beginning',
#  'to',
#  'get',
#  'very',
#  'tired',
#  'of',
#  'sitting',
#  'by',
#  'her',
#  'sister',
#  'on',
#  'the',
#  'bank',
#  'and',
#  'of',
#  'having',
#  'nothing',
#  'to',
#  'do',
#  'once',
#  'or',
#  'twice',
#  'she',
#  'had']

# %%
import random
random.seed(101)
random_pick = random.randint(0,len(text_sequences))

# %%
random_seed_text = text_sequences[random_pick]

# %%
random_seed_text
# Out:
# ['does',
#  'nt',
#  'look',
#  'like',
#  'one',
#  'but',
#  'it',
#  'is',
#  'i',
#  'quite',
#  'agree',
#  'with',
#  'you',
#  'said',
#  'the',
#  'duchess',
#  'and',
#  'the',
#  'moral',
#  'of',
#  'that',
#  'isbe',
#  'what',
#  'you',
#  'would',
#  'seem']

# %%
seed_text = ' '.join(random_seed_text)

# %%
seed_text
# Out:
# 'does nt look like one but it is i quite agree with you said the duchess and the moral of that isbe what you would seem'

# %%
generate_text(model,tokenizer,seq_len,seed_text=seed_text,num_gen_words=200)
# Out:
# Seed text is:  does nt look like one but it is i quite agree with you said the duchess and the moral of that isbe what you would seem
# 'to beor as you d like it was too moreas the baby and got on he began the games in the hedge in another offended was off in alices head and she set to alice like she had rather forgotten she pictured to go dry then the cupboards as i was talking of such a long of a little key and here us thought the fight and himself by her eyes but she was talking as wet the dormouse turned on off and it would not help whether she walked off the right size for herself and twelve like the earth then the blades what marked and on one and twice less him to herself as she ran for her sister prizes she did to be a little hot indeed getting off and then one of one you know now what she was nt a bit afraid to be to get at the glass hair as if he had been a week there was three gardeners at first to eat at the whiting where the time alice had made the fan and concluded the banquet but she tucked her the part call us and behind it and they thinking said'
